# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np

# %%
DATA = 'runtime-tester-output-input-plane-sweep.csv'

# %%
data = pd.read_csv(DATA)
data
# Out:
#    horizontal segments  vertical segments  runtime(ms)
# 0                    2                  4     1.095295
# 1                    2                  6     1.007795

# %%
sns.set()

# t = np.arange(1,26)
# s = x * t + y

plt.plot(data['horizontal segments'] + data['vertical segments'] ,data['runtime(ms)'], label='data')
# plt.plot(t, s, label='approximation')
plt.xlabel('number of segments')
plt.ylabel('execution time (ms)')

plt.legend()

plt.savefig('runtime-plot.png')
